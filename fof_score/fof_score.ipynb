# %% [markdown]
# 产品净值分析

# %%
import numpy as np
import os
import tushare as ts
import pandas as pd
import xlrd
import empyrical as ep
import matplotlib.pyplot as plt
from dateutil.relativedelta import relativedelta
import warnings
warnings.filterwarnings("ignore")
from pyfolio.timeseries import gen_drawdown_table, perf_stats

plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif'] = ['SimHei']

# %% [markdown]
# # 读入产品数据
#
# - excel格式，一个sheet对应一个产品
# - sheet格式，第一列为日期，第二列为累计净值

# %%
file_path = r'./同类产品表.xlsx'
excel = xlrd.open_workbook(file_path)
sheet_list = excel.sheet_names()
df_list = []
for each in sheet_list:
    df = pd.read_excel(file_path, each, header=0)
    if df.empty:
        continue
    df.iloc[:, 0] = pd.to_datetime(df.iloc[:, 0])
    df.set_index(df.iloc[:, 0].name, drop=True, inplace=True)
    df = df.resample('D').asfreq()
    df_list.append(df)
total_raw = pd.concat(df_list, axis=1)

total = total_raw.copy()
trade_list = ts.pro_api().trade_cal(exchange='SSE', start_date=total.index.min().strftime('%Y%m%d'),
                                    end_date=total.index.max().strftime('%Y%m%d'))
trade_list = trade_list[trade_list['is_open'] == 1]  # 交易日
total = total[total.index.isin(pd.to_datetime(trade_list['cal_date']))]
total = total.apply(pd.Series.interpolate)

# %%
total
# Out:
#               圭源蒙玺启航    纯达二期
# 日期
# 2017-07-18  1.000000     NaN
# 2017-07-19  1.000667     NaN
# 2017-07-20  1.001333     NaN
# 2017-07-21  1.002000     NaN
# 2017-07-24  1.001200     NaN
# 2017-07-25  1.000400     NaN
# 2017-07-26  0.999600     NaN
# 2017-07-27  0.998800     NaN
# 2017-07-28  0.998000     NaN
# 2017-07-31  0.998800     NaN
# 2017-08-01  0.999600     NaN
# 2017-08-02  1.000400     NaN
# 2017-08-03  1.001200     NaN
# 2017-08-04  1.002000     NaN
# 2017-08-07  1.002200     NaN
# 2017-08-08  1.002400     NaN
# 2017-08-09  1.002600     NaN
# 2017-08-10  1.002800     NaN
# 2017-08-11  1.003000     NaN
# 2017-08-14  1.003400     NaN
# 2017-08-15  1.003800     NaN
# 2017-08-16  1.004200     NaN
# 2017-08-17  1.004600     NaN
# 2017-08-18  1.005000     NaN
# 2017-08-21  1.005200     NaN
# 2017-08-22  1.005400     NaN
# 2017-08-23  1.005600     NaN
# 2017-08-24  1.005800     NaN
# 2017-08-25  1.006000     NaN
# 2017-08-28  1.006600     NaN
# ...              ...     ...
# 2019-08-23  1.324000  1.2300
# 2019-08-26  1.332400  1.2380
# 2019-08-27  1.340800  1.2460
# 2019-08-28  1.349200  1.2540
# 2019-08-29  1.357600  1.2620
# 2019-08-30  1.366000  1.2700
# 2019-09-02  1.372400  1.2804
# 2019-09-03  1.378800  1.2908
# 2019-09-04  1.385200  1.3012
# 2019-09-05  1.391600  1.3116
# 2019-09-06  1.398000  1.3220
# 2019-09-09  1.396500  1.3200
# 2019-09-10  1.395000  1.3180
# 2019-09-11  1.393500  1.3160
# 2019-09-12  1.392000  1.3140
# 2019-09-16  1.391400  1.3128
# 2019-09-17  1.390800  1.3116
# 2019-09-18  1.390200  1.3104
# 2019-09-19  1.389600  1.3092
# 2019-09-20  1.389000  1.3080
# 2019-09-23  1.388833  1.3075
# 2019-09-24  1.388667  1.3070
# 2019-09-25  1.388500  1.3065
# 2019-09-26  1.388333  1.3060
# 2019-09-27  1.388167  1.3055
# 2019-09-30  1.388000  1.3050
# 2019-10-08  1.386750  1.3035
# 2019-10-09  1.385500  1.3020
# 2019-10-10  1.384250  1.3005
# 2019-10-11  1.383000  1.2990
#
# [544 rows x 2 columns]

# %% [markdown]
# # 计算日收益率

# %%
def value_to_returns(se):
    return se.diff() / se
returns = total.apply(value_to_returns)

# %% [markdown]
# # 表现统计

# %%
def stats_se(se):
    stats = perf_stats(se.dropna())
    # 剔除不在时段内的
    if total_raw[se.name].dropna().index.max()<se.dropna().index.min():
        return None
    stats['VaR'] = np.percentile(se.dropna(), 100 * 0.05)
    stats = stats.append(gen_drawdown_table(se.dropna(), top=1).iloc[0, :])
    return stats

def stats_df(df):
    result = df.apply(stats_se)
    result['mean'] = result.T.mean()
    result['max_min'] = result.apply(lambda x: x.max() - x.min(), axis=1)
    return result

# %% [markdown]
# 指标说明
# > 列：每列为每个产品，mean表示按行计算指标均值，max_min表示按行计算指标的最大值减最小值
#
# > 行：
# - Annual return 年化收益率
# - Cumulative returns累计收益率
# - Annual volatility年化波动率
# - Sharpe ratio夏普比率
# - Calmar ratio卡玛比率
# - Stability稳定性（净值线性回归的R2）
# - Max drawdown最大回撤
# - Omega ratio
# - Sortino ratio
# - Skew
# - Daily value at risk（日收益率均值减去两倍标准差）
# - VaR 在险价值（日收益率的5%分位数）
# - Net drawdown in %	最大回撤百分比
# - Peak date 回撤前高点日期
# - Valley date 最大回撤日期
# - Recovery date 净值恢复日期
# - Duration	 持续天数

# %% [markdown]
# ## 同类产品的统计

# %%
use_returns = returns.copy()
result = stats_df(use_returns)
result.to_csv('./out_stats/同类产品的统计.csv', encoding='gbk')
result
# Out:
#                                   圭源蒙玺启航                 纯达二期       mean  \
# Annual return                   0.159313             0.567044   0.363179
# Cumulative returns               0.37511             0.294938   0.335024
# Annual volatility              0.0507097            0.0682951   0.059502
# Sharpe ratio                     2.94118              6.61685   4.779015
# Calmar ratio                      4.1938              11.5287   7.861275
# Stability                       0.909442             0.955857   0.932649
# Max drawdown                  -0.0379878           -0.0491852  -0.043586
# Omega ratio                      1.97858                3.785   2.881788
# Sortino ratio                    7.51504               18.445  12.980013
# Skew                             2.81446             0.708836   1.761646
# Kurtosis                         12.6544            -0.235876   6.209249
# Tail ratio                       1.68588              2.53973   2.112801
# Daily value at risk          -0.00579697          -0.00681113  -0.006304
# VaR                          -0.00327659          -0.00389525  -0.003586
# Net drawdown in %                3.79878              4.91852   4.358649
# Peak date            2018-08-17 00:00:00  2019-06-06 00:00:00        NaN
# Valley date          2018-10-26 00:00:00  2019-06-21 00:00:00        NaN
# Recovery date        2018-10-31 00:00:00  2019-07-01 00:00:00        NaN
# Duration                              54                   18  36.000000
#
#                                max_min
# Annual return                 0.407731
# Cumulative returns           0.0801715
# Annual volatility            0.0175854
# Sharpe ratio                   3.67568
# Calmar ratio                   7.33495
# Stability                    0.0464151
# Max drawdown                 0.0111974
# Omega ratio                    1.80643
# Sortino ratio                  10.9299
# Skew                           2.10562
# Kurtosis                       12.8902
# Tail ratio                     0.85385
# Daily value at risk         0.00101415
# VaR                        0.000618652
# Net drawdown in %              1.11974
# Peak date            293 days 00:00:00
# Valley date          238 days 00:00:00
# Recovery date        243 days 00:00:00
# Duration                            36

# %% [markdown]
# ## 近3年同类产品的统计

# %%
use_returns = returns[(returns.index.max()-relativedelta(years=3)).strftime('%Y-%m-%d'):]
result = stats_df(use_returns)
result.to_csv('./out_stats/同类产品的统计近3年.csv', encoding='gbk')
result
# Out:
#                                   圭源蒙玺启航                 纯达二期       mean  \
# Annual return                   0.159313             0.567044   0.363179
# Cumulative returns               0.37511             0.294938   0.335024
# Annual volatility              0.0507097            0.0682951   0.059502
# Sharpe ratio                     2.94118              6.61685   4.779015
# Calmar ratio                      4.1938              11.5287   7.861275
# Stability                       0.909442             0.955857   0.932649
# Max drawdown                  -0.0379878           -0.0491852  -0.043586
# Omega ratio                      1.97858                3.785   2.881788
# Sortino ratio                    7.51504               18.445  12.980013
# Skew                             2.81446             0.708836   1.761646
# Kurtosis                         12.6544            -0.235876   6.209249
# Tail ratio                       1.68588              2.53973   2.112801
# Daily value at risk          -0.00579697          -0.00681113  -0.006304
# VaR                          -0.00327659          -0.00389525  -0.003586
# Net drawdown in %                3.79878              4.91852   4.358649
# Peak date            2018-08-17 00:00:00  2019-06-06 00:00:00        NaN
# Valley date          2018-10-26 00:00:00  2019-06-21 00:00:00        NaN
# Recovery date        2018-10-31 00:00:00  2019-07-01 00:00:00        NaN
# Duration                              54                   18  36.000000
#
#                                max_min
# Annual return                 0.407731
# Cumulative returns           0.0801715
# Annual volatility            0.0175854
# Sharpe ratio                   3.67568
# Calmar ratio                   7.33495
# Stability                    0.0464151
# Max drawdown                 0.0111974
# Omega ratio                    1.80643
# Sortino ratio                  10.9299
# Skew                           2.10562
# Kurtosis                       12.8902
# Tail ratio                     0.85385
# Daily value at risk         0.00101415
# VaR                        0.000618652
# Net drawdown in %              1.11974
# Peak date            293 days 00:00:00
# Valley date          238 days 00:00:00
# Recovery date        243 days 00:00:00
# Duration                            36

# %% [markdown]
# ## 近1年同类产品的统计

# %%
use_returns = returns[(returns.index.max()-relativedelta(years=1)).strftime('%Y-%m-%d'):]
result = stats_df(use_returns)
result.to_csv('./out_stats/同类产品的统计近1年.csv', encoding='gbk')
result
# Out:
#                                   圭源蒙玺启航                 纯达二期       mean  \
# Annual return                   0.157554             0.567044   0.362299
# Cumulative returns               0.15219             0.294938   0.223564
# Annual volatility              0.0528002            0.0682951   0.060548
# Sharpe ratio                     2.79799              6.61685   4.707420
# Calmar ratio                     4.69584              11.5287   8.112296
# Stability                         0.7367             0.955857   0.846279
# Max drawdown                  -0.0335518           -0.0491852  -0.041368
# Omega ratio                      1.67304                3.785   2.729019
# Sortino ratio                    6.07291               18.445  12.258949
# Skew                             1.53569             0.708836   1.122262
# Kurtosis                         3.76761            -0.235876   1.765869
# Tail ratio                       1.81749              2.53973   2.178609
# Daily value at risk          -0.00606596          -0.00681113  -0.006439
# VaR                          -0.00342237          -0.00389525  -0.003659
# Net drawdown in %                3.35518              4.91852   4.136850
# Peak date            2019-04-12 00:00:00  2019-06-06 00:00:00        NaN
# Valley date          2019-05-10 00:00:00  2019-06-21 00:00:00        NaN
# Recovery date        2019-08-07 00:00:00  2019-07-01 00:00:00        NaN
# Duration                              84                   18  51.000000
#
#                               max_min
# Annual return                 0.40949
# Cumulative returns           0.142748
# Annual volatility           0.0154949
# Sharpe ratio                  3.81887
# Calmar ratio                  6.83291
# Stability                    0.219157
# Max drawdown                0.0156334
# Omega ratio                   2.11196
# Sortino ratio                 12.3721
# Skew                         0.826851
# Kurtosis                      4.00349
# Tail ratio                   0.722234
# Daily value at risk       0.000745168
# VaR                       0.000472874
# Net drawdown in %             1.56334
# Peak date            55 days 00:00:00
# Valley date          42 days 00:00:00
# Recovery date        37 days 00:00:00
# Duration                           66

# %% [markdown]
# # 同类产品合成

# %% [markdown]
# ## 等权法

# %% [markdown]
# - 计算原始数据，有缺失值的产品不参与加权。

# %%
new_returns = returns.copy()
new_returns['new'] = returns.mean(axis=1)
new_value = new_returns.cumsum()+1.0
new_value.to_csv('./out_new/同类产品等权合成.csv', encoding='gbk')

# %% [markdown]
# ## 加权法

# %% [markdown]
# - 设置权重，有缺失值的产品不参与加权，并重新将参与加权的产品权重归一化，保持产品间比例不变。
# - weight与returns数据结构保持一致。

# %%
# 设置权重
weight = [0.5, 0.3, 0.2]
assert len(weight)==len(returns.columns)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-7c91be296991> in <module>()
#       1 # 设置权重
#       2 weight = [0.5, 0.3, 0.2]
# ----> 3 assert len(weight)==len(returns.columns)
#
# AssertionError:

# %%
def weight_se(se, weight):
    if se.dropna().empty:
        return np.nan
    # na位置
    temp = pd.Series(weight, index=se.index)
    use_se = se[~se.isnull()]
    use_temp = temp[~se.isnull()]
    use_temp = use_temp/use_temp.sum()
    return np.matmul(use_se, use_temp).sum()

new_returns = returns.copy()
new_returns['new'] = new_returns.apply(weight_se, axis=1, args=(weight,))
new_value = new_returns.cumsum()+1.0
new_value.to_csv('./out_new/同类产品加权合成.csv', encoding='gbk')
